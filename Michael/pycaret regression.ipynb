# %%
import pandas as pd
import numpy as np
from pycaret.regression import *
import datetime

# %%
data=pd.read_csv('Security_and_market_movement_unscaled_cluster_weekly_125.csv')

# %%
data.dtypes
# Out:
# Unnamed: 0                                            int64
# SecurityID                                          float64
# KeyDate                                              object
# YieldWorst                                          float64
# ModifiedDuration_Plain                              float64
# AmtOutstanding                                      float64
# Target_G_change                                     float64
# YieldWorst_change                                   float64
# ModifiedDuration_Plain_change                       float64
# Group                                                object
# Cluster_average_AmountIssued                        float64
# Cluster_average_Coupon                              float64
# Cluster_average_Term                                float64
# Cluster_average_Rating                              float64
# Cluster Perecentage of Jr Subordinated Unsecured    float64
# Cluster Perecentage of Secured                      float64
# ...

# %%
#data['Cluster_G_change'] = data['Cluster_G_change'] * (10000)
#data['Target_G_change'] = data['Target_G_change'] * (10000)

# %% [markdown]
# data = data.rename(columns={ 'Jr Subordinated Unsecured':'Cluster Perecentage of Jr Subordinated Unsecured',
#                      'Secured':'Cluster Perecentage of Secured',
#                      'Sr Unsecured':'Cluster Perecentage of Unsecured',
#                      'Subordinated Unsecured':'Cluster Perecentage of Subordinated Unsecured',
#                      '1st Lien Secured':'Cluster Perecentage of 1st Lien Secured',
#                      '2nd Lien Secured':'Cluster Perecentage of 2nd Lien Secured',
#                      '3rd Lien Secured':'Cluster Perecentage of 3rd Lien Secured',
#                      '1st lien':'Cluster Perecentage of 1st Lien',
#                      'Asset Backed':'Cluster Perecentage of Asset Backed'})

# %%
data['KeyDate'] = pd.to_datetime(data['KeyDate'])

# %%
df=data

# %%
data.drop(columns=['Unnamed: 0','KeyDate','SecurityID','Group','Cluster Perecentage of Asset Backed'],inplace=True)

# %%
data_1.drop(columns=['Unnamed: 0','KeyDate','SecurityID','Group','Cluster Perecentage of Asset Backed'],inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
reg=setup(data=data,target='Target_G_change',normalize=True,transformation=True,transform_target=False,
         remove_outliers=True,outliers_threshold=0.05)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcbrow4_col1 {
#             background-color:  yellow;
#         }    #T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcbrow15_col1 {
#             background-color:  yellow;
#         }    #T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcbrow17_col1 {
#             background-color:  yellow;
#         }    #T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcbrow26_col1 {
#             background-color:  yellow;
#         }</style><table id="T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0c3676a8_f6b3_11ea_8eb9_b081430cbdcblevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
weekly_total=compare_models(whitelist=['xgboost','rf','gbr'])
# Out:
# <style  type="text/css" >
#     #T_faccbce6_f6c5_11ea_98d2_b081430cbdcb th {
#           text-align: left;
#     }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col0 {
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col1 {
#             : ;
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col5 {
#             : ;
#             text-align:  left;
#         }    #T_faccbce6_f6c5_11ea_98d2_b081430cbdcbrow0_col6 {
#             : ;
#             text-align:  left;
# ...

# %%
#data_1 = data[data['KeyDate']<= datetime.datetime(2019,2,28)]
reg_1=setup(data=data_1,target='Target_G_change',normalize=True,transformation=True,transform_target=False,
         remove_outliers=True,outliers_threshold=0.05)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcbrow4_col1 {
#             background-color:  yellow;
#         }    #T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcbrow15_col1 {
#             background-color:  yellow;
#         }    #T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcbrow17_col1 {
#             background-color:  yellow;
#         }    #T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcbrow26_col1 {
#             background-color:  yellow;
#         }</style><table id="T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cdc81ae2_f6cd_11ea_85d8_b081430cbdcblevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
week1=compare_models(whitelist=['rf','xgboost','gbr'])
# Out:
# <style  type="text/css" >
#     #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcb th {
#           text-align: left;
#     }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col0 {
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_6561d8f6_f6d0_11ea_a0b0_b081430cbdcbrow0_col6 {
#             : ;
# ...

# %%
data_2 = df.loc[(datetime.datetime(2019,2,28)<=df['KeyDate'])& (df['KeyDate']<= datetime.datetime(2019,3,28))]

# %%
March=setup(data=data_2,target='Target_G_change',normalize=True,transformation=True,transform_target=False,
         remove_outliers=True,outliers_threshold=0.05)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_0089cad8_f763_11ea_891a_b081430cbdcbrow15_col1 {
#             background-color:  yellow;
#         }    #T_0089cad8_f763_11ea_891a_b081430cbdcbrow17_col1 {
#             background-color:  yellow;
#         }    #T_0089cad8_f763_11ea_891a_b081430cbdcbrow26_col1 {
#             background-color:  yellow;
#         }</style><table id="T_0089cad8_f763_11ea_891a_b081430cbdcb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_0089cad8_f763_11ea_891a_b081430cbdcblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_0089cad8_f763_11ea_891a_b081430cbdcbrow0_col0" class="data row0 col0" >session_id</td>
# ...

# %%
March_model=compare_models(whitelist=['rf','xgboost','gbr'])
# Out:
# <style  type="text/css" >
#     #T_49ff90c0_f764_11ea_b774_b081430cbdcb th {
#           text-align: left;
#     }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col0 {
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_49ff90c0_f764_11ea_b774_b081430cbdcbrow0_col6 {
#             : ;
# ...

# %%
data_3 = df.loc[(datetime.datetime(2019,3,28)<=df['KeyDate'])& (df['KeyDate']<= datetime.datetime(2019,4,28))]
data_3.drop(columns=['Unnamed: 0','KeyDate','SecurityID','Group','Cluster Perecentage of Asset Backed'],inplace=True)
April=setup(data=data_3,target='Target_G_change',normalize=True,transformation=True,transform_target=False,
         remove_outliers=True,outliers_threshold=0.05)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_db13b02c_f764_11ea_a32d_b081430cbdcbrow15_col1 {
#             background-color:  yellow;
#         }    #T_db13b02c_f764_11ea_a32d_b081430cbdcbrow17_col1 {
#             background-color:  yellow;
#         }    #T_db13b02c_f764_11ea_a32d_b081430cbdcbrow26_col1 {
#             background-color:  yellow;
#         }</style><table id="T_db13b02c_f764_11ea_a32d_b081430cbdcb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_db13b02c_f764_11ea_a32d_b081430cbdcblevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_db13b02c_f764_11ea_a32d_b081430cbdcbrow0_col0" class="data row0 col0" >session_id</td>
# ...

# %%
April_model=compare_models(whitelist=['rf','xgboost','gbr'])
# Out:
# <style  type="text/css" >
#     #T_2dd2e96c_f766_11ea_93cc_b081430cbdcb th {
#           text-align: left;
#     }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col0 {
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_2dd2e96c_f766_11ea_93cc_b081430cbdcbrow0_col6 {
#             : ;
# ...

# %%
data_4 = df.loc[(datetime.datetime(2019,4,28)<df['KeyDate'])& (df['KeyDate']<= datetime.datetime(2019,5,28))]
data_4.drop(columns=['Unnamed: 0','KeyDate','SecurityID','Group','Cluster Perecentage of Asset Backed'],inplace=True)
May=setup(data=data_4,target='Target_G_change',normalize=True,transformation=True,transform_target=False,
         remove_outliers=True,outliers_threshold=0.05)
# Out:
#
# Setup Succesfully Completed.
# <style  type="text/css" >
#     #T_4c4fba9e_f766_11ea_8847_b081430cbdcbrow4_col1 {
#             background-color:  yellow;
#         }    #T_4c4fba9e_f766_11ea_8847_b081430cbdcbrow15_col1 {
#             background-color:  yellow;
#         }    #T_4c4fba9e_f766_11ea_8847_b081430cbdcbrow17_col1 {
#             background-color:  yellow;
#         }    #T_4c4fba9e_f766_11ea_8847_b081430cbdcbrow26_col1 {
#             background-color:  yellow;
#         }</style><table id="T_4c4fba9e_f766_11ea_8847_b081430cbdcb" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c4fba9e_f766_11ea_8847_b081430cbdcblevel0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
May_model=compare_models(blacklist=['svm'])
# Out:
# <style  type="text/css" >
#     #T_248da98c_f769_11ea_969b_b081430cbdcb th {
#           text-align: left;
#     }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col0 {
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col1 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col2 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col3 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col4 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col5 {
#             background-color:  yellow;
#             text-align:  left;
#         }    #T_248da98c_f769_11ea_969b_b081430cbdcbrow0_col6 {
#             : ;
# ...
